# %%
#Lect_0623a followup
#This notebook has information about how to read, edit and save text and cvs files

# %%
#Step 1: Import important function 

import math                      #Math functions
import numpy as np               #Packege for matrix and vectore analysis or something like that
import matplotlib as mpl         #Graphs data (need numpy to work)
import matplotlib.pyplot as plt  #Graphs like in Matlab
